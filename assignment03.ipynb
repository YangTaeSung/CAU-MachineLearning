# %% [markdown]
# <a href="https://colab.research.google.com/github/YangTaeSung/CAU-MachineLearning/blob/master/assignment03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Assignment03

# %%
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
from matplotlib.ticker import MaxNLocator
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # 1.Input points

# %%
"""
from google.colab import files

uploaded = files.upload()
path = "data.csv"
data = np.genfromtxt(path, delimiter=',')
  
for fn in uploaded.keys():
        print('User uploaded file "{name}" with length {length} bytes'.format(name = fn, length=len(uploaded[fn])))
"""
# Out:
# '\nfrom google.colab import files\n\nuploaded = files.upload()\npath = "data.csv"\ndata = np.genfromtxt(path, delimiter=\',\')\n  \nfor fn in uploaded.keys():\n        print(\'User uploaded file "{name}" with length {length} bytes\'.format(name = fn, length=len(uploaded[fn])))\n'

# %%
path = "data.csv"
data = np.genfromtxt(path, delimiter=',')

x_data = data[:, 0]
y_data = data[:, 1]

plt.figure(figsize=(8, 8)) # 그래프 사이즈 조절
plt.scatter(x_data, y_data, c = 'black', alpha = 0.5) # alpha : 투명도
plt.title('Linear function')
plt.xlabel('X AXIS')
plt.ylabel('Y AXIS')
plt.show()

# %% [markdown]
# ### [1] plot a set of points {(x(i), y(i))} that are loaded from 'data.csv' file (in black color)

# %%
thetaZero = 0.0
thetaOne = 0.0

cycle = 3000
learningLate = 0.009

# %% [markdown]
# * 세타값 초기화(learning 시작점)
# * Optimization cycle과 learning late 설정

# %%
iForGraph = []
jFor3D = []
newThetaOne = []
newThetaZero = []
noiseNum = len(x_data)

# %% [markdown]
# * Plotting을 위한 각종 데이터 저장 변수 정의

# %%
for i in range(cycle):

  h = thetaZero + thetaOne * x_data
  j = np.sum((h - y_data) ** 2) / (2 * noiseNum)

  thetaZero = thetaZero - learningLate / noiseNum * np.sum((thetaOne * x_data - y_data + thetaZero))
  thetaOne = thetaOne - learningLate / noiseNum * np.sum((thetaOne * x_data - y_data + thetaZero) * x_data)
  
  iForGraph.append(i)
  jFor3D.append(j)
  newThetaOne.append(thetaOne)
  newThetaZero.append(thetaZero)
  
  if i % 100 == 0:
        print('cycle : {:10d} cost: {:10f} thetaZero: {:10f} thetaOne: {:10f}'.format(i, j,thetaZero, thetaOne))

finalY = thetaOne * x_data + thetaZero
# Out:
# cycle :          0 cost: 1827.967043 thetaZero:   0.180589 thetaOne:   2.810255
# cycle :        100 cost:  79.248332 thetaZero:  14.784898 thetaOne:   9.780156
# cycle :        200 cost:  36.072824 thetaZero:  20.780849 thetaOne:   9.871660
# cycle :        300 cost:  28.897601 thetaZero:  23.225163 thetaOne:   9.908963
# cycle :        400 cost:  27.705170 thetaZero:  24.221614 thetaOne:   9.924170
# cycle :        500 cost:  27.507003 thetaZero:  24.627828 thetaOne:   9.930369
# cycle :        600 cost:  27.474071 thetaZero:  24.793425 thetaOne:   9.932896
# cycle :        700 cost:  27.468598 thetaZero:  24.860933 thetaOne:   9.933927
# cycle :        800 cost:  27.467688 thetaZero:  24.888453 thetaOne:   9.934346
# cycle :        900 cost:  27.467537 thetaZero:  24.899672 thetaOne:   9.934518
# cycle :       1000 cost:  27.467512 thetaZero:  24.904246 thetaOne:   9.934588
# cycle :       1100 cost:  27.467508 thetaZero:  24.906110 thetaOne:   9.934616
# ...

# %% [markdown]
# * Gradient descent algorithm
# * list.append 함수를 사용하여 optimization 단계마다 각각의 값 저장
# * 100cycle 주기로 출력
# * Optimal한 linear함수 finalY 정의

# %% [markdown]
# # 2.Linear regression result

# %%
plt.figure(figsize=(8, 8)) # 그래프 사이즈 조절
plt.scatter(x_data, y_data, c = 'black', alpha = 0.5) # alpha : 투명도
plt.plot(x_data, finalY, "RED")
plt.title('Linear function')
plt.xlabel('X AXIS')
plt.ylabel('Y AXIS')
plt.show()

# %% [markdown]
# ### [1] plot a set of points {(x(i),y(i))} that are loaded from 'data.csv' file (in black color)
# ### [2] plot a straight line obtained by the optimal linear regression based on the given set of points (in red color)
# ### [3] the estimated straight line (linear function) is superimposed on the set of points

# %%
cycleFor3d = 600;

thetaOne3d = -30
thetaZero3d = -30
z = []

# %%
for u in range(cycleFor3d):

  h = thetaZero3d + thetaOne3d * x_data
  j = np.sum((h - y_data) ** 2) / (2 * noiseNum)

  thetaZero3d = thetaZero3d + 0.1
  thetaOne3d = thetaOne3d + 0.1 
  
  z.append(j)
  newThetaOne.append(thetaOne)
  newThetaZero.append(thetaZero)
  
  if u % 100 == 0:
        print('cycle : {:10d} cost: {:10f} thetaZero: {:10f} thetaOne: {:10f}'.format(u, j,thetaZero3d, thetaOne3d))
# Out:
# cycle :          0 cost: 26495.765764 thetaZero: -29.900000 thetaOne: -29.900000
# cycle :        100 cost: 15006.286256 thetaZero: -19.900000 thetaOne: -19.900000
# cycle :        200 cost: 6783.686682 thetaZero:  -9.900000 thetaOne:  -9.900000
# cycle :        300 cost: 1827.967043 thetaZero:   0.100000 thetaOne:   0.100000
# cycle :        400 cost: 139.127338 thetaZero:  10.100000 thetaOne:  10.100000
# cycle :        500 cost: 1717.167567 thetaZero:  20.100000 thetaOne:  20.100000

# %%
x = np.linspace(-30,30,200) # thetaZero 가정
y = np.linspace(-30,30,200) # -30~30 0.1 간격으로 배열 생성
x,y = np.meshgrid(x,y)
# z = np.array(z)
# z = x**2 + y**2
# z = np.sum(((x + y * x_data) - y_data ) ** 2) / ( 2 * noiseNum)
z = ((x + y * x_data) - y_data ) ** 2 / ( 2 * noiseNum)

# %%
x.shape
y.shape
# z.shape
# Out:
# (200, 200)

# %%
# 세타0, 세타1, J을 3차원으로 표현
fig = plt.figure(figsize=(8,8)) 
ax = fig.gca(projection='3d')
# ax = fig.add_subplot(111, projection='3d')
# ax = Axes3D(fig)
# ax.plot_trisurf(x, y, z, color = 'white', edgecolors='grey', alpha=0.5)

surf = ax.plot_surface(x, y, z, rstride=2, cstride=2, cmap=cm.RdPu, linewidth=1, antialiased=True)

plt.show()
